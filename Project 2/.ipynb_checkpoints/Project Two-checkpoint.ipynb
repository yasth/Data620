# %% [markdown]
# # Project 2

# %% [markdown]
# # Week 7 | Project - 2
# Group 4: Joshua Hummell, Jiho Kim, Scott Reed

# %% [markdown]
# 1. Identify a large 2-node network dataset—you can start with a dataset in a repository.  Your data should meet the criteria that it consists of ties between and not within two (or more) distinct groups.

# %% [markdown]
# ## Data load
#
# The first thing we want to do is load the packages and data. The data is from a Facebook-like Forum Network we: [https://toreopsahl.com/datasets/#online_forum_network](https://toreopsahl.com/datasets/#online_forum_network). The data represents an two-mode network among 899 users and 522 topics. The connections are weighted the number of messages or characters that a user posted about a topic.

# %%
import matplotlib.pyplot as plt
import networkx as nx
import networkx.algorithms.bipartite as bipartite
import pandas as pd

# %%
SN_Data = pd.read_csv("https://raw.githubusercontent.com/jhumms/620/main/project-2/social_network_data.csv")
SN_Data.head()
# Out:
#    user  topic  weight
# 0     1      1       1
# 1     1     39       9
# 2     1    102       2
# 3     1    154       1
# 4     1    357       5

# %%
G = nx.convert_matrix.from_pandas_edgelist(SN_Data,source='user', target='topic', edge_attr="weight")

# %%
plt.figure(figsize=(10,10))
pos = nx.spring_layout(G, seed=648)  # Seed layout for reproducible node positions
nx.draw(G, pos, with_labels=False)
plt.show()

# %%
sorted(G.degree, key=lambda x: x[1], reverse=True)[0:10]
# Out:
# [(10, 128),
#  (13, 122),
#  (67, 113),
#  (82, 102),
#  (164, 102),
#  (100, 100),
#  (75, 96),
#  (12, 95),
#  (18, 92),
#  (59, 87)]

# %%
nx.info(G)
# Out:
# 'Graph with 899 nodes and 7046 edges'

# %%
nx.density(G)
# Out:
# 0.017455673341574777

# %%
nx.diameter(G)
# Out:
# 6

# %%
nx.is_connected(G)
# Out:
# True

# %%
view = nx.subgraph_view(G, filter_edge=G.nodes)
subGraph = nx.Graph(view)
subGraph.remove_nodes_from(list(nx.isolates(subGraph)))
subGraph.edges()
nx.info(subGraph)
# Out:
# 'Graph with 899 nodes and 7046 edges'

# %%
f = plt.figure(figsize=(20,20))
f.tight_layout()
nx.draw_networkx(subGraph)
plt.show()

# %%
view = nx.subgraph_view(G, filter_edge=G.edges)
subGraph = nx.Graph(view)
subGraph.remove_nodes_from(list(nx.isolates(subGraph)))
subGraph.edges()
nx.info(subGraph)
# Out:
# 'Name: \nType: Graph\nNumber of nodes: 899\nNumber of edges: 7046\nAverage degree:  15.6752'

# %%
f = plt.figure(figsize=(20,20))
f.tight_layout()
nx.draw_networkx(subGraph)
plt.show()

# %%
# Trimming edges based on edge weight
def trim_edges(G, weight=1):
    fb_g2 = net.Graph()
    for f, to, edata in G.edges(data=True):
        if edata['weight']> weight:
            fb_g2.add_edge(f,to,edata)
    return fb_g2

# %% [markdown]
# 2. Reduce the size of the network using a method such as the island method described in chapter 4 of social network analysis.

# %%
plt.plot(SN_Data['weight'])

# %%
users = []
topics = []
G = nx.Graph()

for row in SN_Data:
    if row[0] not in users:
        users.append(row[0])
    if row[1] not in topics:
        topics.append(row[1])
    G.add_edge(row[0], row[1], weight = row[2])

# %%
def filter_edge(n1, n2):
    #print(n1,n2)
    return "n[]" == n2 or "Beer" == n1

view = nx.subgraph_view(G, filter_edge=filter_edge)
subGraph = nx.Graph(view)
subGraph.remove_nodes_from(list(nx.isolates(subGraph)))
subGraph.edges()
nx.info(subGraph)


view = nx.subgraph_view(G, filter_edge=filter_edge)

# %%
# Trimming edges based on edge weight
user_net = nx.algorithms.bipartite.weighted_projected_graph(G, users, ratio=False)



weights = [math.log(edata['weight'])for f,t,edata in user_net.edges(data=True)]

topic_net = nx.algorithms.bipartite.weighted_projected_graph(G, topics, ratio=False)
topic_net = max((nx.connected_components(user_net)))
tweights = [math.log(edata['weight'])for f,t,edata in user_net.edges(data=True)]

# %%
def trim_edges(G, weight=1):
    g2 = net.Graph()
    for f, to, edata in G.edges(data=True):
        if edata['weight']> weight:
            g2.add_edge(f,to,edata)
    return g2
