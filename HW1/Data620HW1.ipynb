# %% [markdown]
# # Data 620
# Scott Reed
# ### HW 1

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()
G.add_nodes_from(range(0,9))
G.add_edges_from([(9, 8), (8, 7),(7, 6),(7, 5),(5,6),(5,2)
                  ,(5,0),(5,3),(6,3),(6,4),(6,1),(2,0),(2,3),(3,1),(3,4),(3,0),(4,1),(0,1)])
nx.draw(G, with_labels=True, font_weight='bold')
